# %% [markdown]
# # Plotting Sigmoid Function

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import matplotlib.colors
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
from tqdm import tqdm_notebook

# %%
# import seaborn as sns

# sns.set()

# %% [markdown]
# <h2> Sigmoid Function</h2>
#
# $S_{w, b}(x) = \frac{1}{1 + e^{-(wx + b)}}$

# %%
def sigmoid(x, w, b):
  return 1 / (1 + np.exp(-(w*x + b)))

# %%
sigmoid(1, 0.5, 0)
# Out:
# 0.6224593312018546

# %%
w = -0.6    #@param {type: "slider", min: -2, max: 2, step: 0.1}
b = -2  #@param {type: "slider", min: -2, max: 2, step: 0.1}
X = np.linspace(-10,10,100)
Y = sigmoid(X, w, b)

plt.plot(X, Y)
plt.show()

# %%
w = -0.6    #@param {type: "slider", min: -2, max: 2, step: 0.1}
b = -1  #@param {type: "slider", min: -2, max: 2, step: 0.1}
X = np.linspace(-10,10,100)
Y = sigmoid(X, w, b)

plt.plot(X, Y)
plt.show()

# %%
w = 1.5    #@param {type: "slider", min: -2, max: 2, step: 0.1}
b = -1  #@param {type: "slider", min: -2, max: 2, step: 0.1}
X = np.linspace(-10,10,100)
Y = sigmoid(X, w, b)

plt.plot(X, Y)
plt.show()

# %%
w = 1.5    #@param {type: "slider", min: -2, max: 2, step: 0.1}
b = 0  #@param {type: "slider", min: -2, max: 2, step: 0.1}
X = np.linspace(-10,10,100)
Y = sigmoid(X, w, b)

plt.plot(X, Y)
plt.show()

# %%
w = 0.5    #@param {type: "slider", min: -2, max: 2, step: 0.1}
b = 2  #@param {type: "slider", min: -2, max: 2, step: 0.1}
X = np.linspace(-10,10,100)
Y = sigmoid(X, w, b)

plt.plot(X, Y)
plt.show()

# %%
w = 0.5    #@param {type: "slider", min: -2, max: 2, step: 0.1}
b = -2  #@param {type: "slider", min: -2, max: 2, step: 0.1}
X = np.linspace(-10,10,100)
Y = sigmoid(X, w, b)

plt.plot(X, Y)
plt.show()

# %% [markdown]
# <h2>2D sigmoid</h2>
#
# $S_{w_1, w_2, b}(x_1, x_2) = \frac{1}{1 + e^{-(w_1x_1 + w_2x_2 + b)}}$

# %%
def sigmoid_2d(x1, x2, w1, w2, b):
  return 1 / (1 + np.exp(-(w1*x1 + w2*x2 + b)))

# %%
sigmoid_2d(1, 0, 0.5, 0, 0)
# Out:
# 0.6224593312018546

# %%
x1 = np.linspace(-10, 10, 100)
x2 = np.linspace(-10, 10, 100)

xx1, xx2 = np.meshgrid(x1, x2)

print(x1.shape, x2.shape, xx1.shape, xx2.shape)

# mesh grid given one dimensional array, converts into equivalent dimension grid


# x1 = np.linspace(-10, 10, 50)
# x2 = np.linspace(-10, 10, 50)

# xx1, xx2 = np.meshgrid(x1, x2)

# print(x1.shape, x2.shape, xx1.shape, xx2.shape)
# Out:
# (100,) (100,) (100, 100) (100, 100)

# %%
w1 = 2
w2 = -0.5
b = 0
Y = sigmoid_2d(xx1, xx2, w1, w2, b)

# %%
my_cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["red", "yellow", "green"])

# %%
plt.contourf(xx1, xx2, Y, cmap=my_cmap, alpha=0.6)
plt.show()

# %%
fig = plt.figure(figsize=(9,6))
ax = plt.axes(projection='3d')
ax.plot_surface(xx1, xx2, Y, cmap='viridis')
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('y')

ax.view_init(30, 270)

# %% [markdown]
# # compute loss for a given dataset

# %%
w_unknw = 0.5
b_unknw = 0.25

X = np.random.random(25) * 20 - 10
Y = sigmoid(X, w_unknw, b_unknw)

# %%
X.shape, Y.shape
# Out:
# ((25,), (25,))

# %%
X[0]
# Out:
# -9.544943409744244

# %%
plt.plot(X, Y, '*')
plt.show()

# %%
def calculate_loss(X, Y, w_est, b_est):
  loss = 0
  for x, y in zip(X, Y):
    loss += (y - sigmoid(x, w_est, b_est))**2
  return loss

# %%
W = np.linspace(0, 2, 101)
B = np.linspace(-1, 1, 101)

WW, BB = np.meshgrid(W, B)

Loss = np.zeros(WW.shape)

WW.shape, BB.shape, W.shape, B.shape
# Out:
# ((101, 101), (101, 101), (101,), (101,))

# %%
Loss.shape
# Out:
# (101, 101)

# %%
sigmoid(X[0], 0.0, 0.0), Y[0], Y[0] - sigmoid(X[0], 0.0, 0.0), (Y[0] - sigmoid(X[0], 0.0, 0.0))**2
# Out:
# (0.5, 0.010745424123087289, -0.48925457587691273, 0.23937004001649775)

# %%
s_v = (Y[0] - sigmoid(X[0], 0.0, 0.0))**2
type(s_v),
# Out:
# (numpy.float64,)

# %%
WW.shape
# Out:
# (101, 101)

# %%
W[:5]
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08])

# %%
WW[:5, :5]
# Out:
# array([[0.  , 0.02, 0.04, 0.06, 0.08],
#        [0.  , 0.02, 0.04, 0.06, 0.08],
#        [0.  , 0.02, 0.04, 0.06, 0.08],
#        [0.  , 0.02, 0.04, 0.06, 0.08],
#        [0.  , 0.02, 0.04, 0.06, 0.08]])

# %%
Loss[0, 0]
# Out:
# 0.0

# %%
l = calculate_loss(X, Y, WW[0, 0], BB[0, 0])
type(l)
# Out:
# numpy.float64

# %%
l.shape
# Out:
# ()

# %%
Loss[0][0]
# Out:
# 0.0

# %%
for i in range(WW.shape[0]):
  for j in range(WW.shape[1]):
    Loss[i, j] = calculate_loss(X, Y, WW[i, j], BB[i, j])

# %%
fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection='3d')
ax.plot_surface(WW, BB, Loss, cmap='viridis')
ax.set_xlabel('W')
ax.set_ylabel('b')
ax.set_zlabel('Loss')

ax.view_init(30, 270)

# %%
ij = np.argmin(Loss)
i = int(np.floor(ij / Loss.shape[1]))
j = int(ij - i * Loss.shape[1])

# %%
print(i, j)
# Out:
# 62 25

# %%
print(WW[i,j], BB[i,j])
# Out:
# 0.5 0.24

# %%
w = np.random.randn(1, 30)
w.shape
# Out:
# (1, 30)

# %%
w
# Out:
# array([[ 0.82063854,  0.52763018,  1.7163128 ,  2.07224816,  1.09803107,
#          0.35294759, -2.27696895, -0.64894352,  1.55389812,  1.13752936,
#         -0.94671722,  0.12150382, -0.17446917, -0.41786712,  0.31186652,
#         -2.32698355,  0.9316598 , -0.27063118,  1.61945501, -1.44500924,
#         -0.84785444,  0.26524111, -0.67306429,  1.02289734, -0.53895828,
#         -0.37249344,  1.18653101, -0.88969387, -1.12722298, -0.64608346]])

# %%
dw = 0.3
w -= dw
w
# Out:
# array([[ 0.52063854,  0.22763018,  1.4163128 ,  1.77224816,  0.79803107,
#          0.05294759, -2.57696895, -0.94894352,  1.25389812,  0.83752936,
#         -1.24671722, -0.17849618, -0.47446917, -0.71786712,  0.01186652,
#         -2.62698355,  0.6316598 , -0.57063118,  1.31945501, -1.74500924,
#         -1.14785444, -0.03475889, -0.97306429,  0.72289734, -0.83895828,
#         -0.67249344,  0.88653101, -1.18969387, -1.42722298, -0.94608346]])

# %% [markdown]
# # Class for sigmoid neuron

# %%
class SigmoidNeuron:
  
  def __init__(self):
    self.w = None
    self.b = None
  
  def perceptron(self, x):
    return np.dot(x, self.w.T) + self.b
  
  def sigmoid(self, x):
    return 1.0/(1.0 + np.exp(-x))
  
  def grad_w(self, x, y):
    y_pred = self.sigmoid(self.perceptron(x))
    return (y_pred - y) * y_pred * (1 - y_pred) * x
  
  def grad_b(self, x, y):
    y_pred = self.sigmoid(self.perceptron(x))
    return (y_pred - y) * y_pred * (1 - y_pred) * 1
  
  def fit(self, X, Y, epochs=1, learning_rate=1, initialize=True, display_loss=False):
    
    if initialize:
      self.w = np.random.randn(1, X.shape[1])
      self.b = 0
    
    if display_loss:
      loss = {}
    
    
    for i in tqdm_notebook(range(epochs), total=epochs, unit='epoch'):
      dw = 0
      db = 0
      for x, y in zip(X, Y):
#         if i == 0:
#           dw += self.grad_w(x, y)
#           db += self.grad_b(x, y)
#           print(type(dw), dw.shape)
#           print(type(db), db.shape)
        dw += self.grad_w(x, y)
        db += self.grad_b(x, y)
      self.w -= learning_rate * dw
      self.b -= learning_rate * db
      
      if display_loss:
        Y_pred = self.sigmoid(self.perceptron(X))
        loss[i] = mean_squared_error(Y_pred, Y)
    
    if display_loss:
      plt.plot(loss.values())
      plt.xlabel('Epochs')
      plt.ylabel('Mean Squared Error')
      plt.show()
    
  def predict(self, X):
    Y_pred = []
    for x in X:
      y_pred = self.sigmoid(self.perceptron(x))
      Y_pred.append(y_pred)
    return np.array(Y_pred)

# %% [markdown]
# # Fit for toy data

# %%
X = np.asarray([[2.5, 2.5], [4, -1], [1, -4], [-3, 1.25], [-2, -4], [1, 5]])
Y = [1, 1, 1, 0, 0, 0]

# %%
sn = SigmoidNeuron()
sn.fit(X, Y, 1, 0.25, True)
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)

# %%
def plot_sn(X, Y, sn, ax):
  X1 = np.linspace(-10, 10, 100)
  X2 = np.linspace(-10, 10, 100)
  XX1, XX2 = np.meshgrid(X1, X2)
  YY = np.zeros(XX1.shape)
  for i in range(X2.size):
    for j in range(X1.size):
      val = np.asarray([X1[j], X2[i]])
      YY[i, j] = sn.sigmoid(sn.perceptron(val))
  ax.contourf(XX1, XX2, YY, cmap=my_cmap, alpha=0.6)
  ax.scatter(X[:,0], X[:,1],c=Y, cmap=my_cmap)
  ax.plot()

# %%
sn.fit(X, Y, 1, 0.05, True)
N = 30
plt.figure(figsize=(10, N*5))
for i in range(N):
  print(sn.w, sn.b)
  ax = plt.subplot(N, 1, i + 1)
  plot_sn(X, Y, sn, ax)
  sn.fit(X, Y, 1, 0.5, False)
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 0.60817035 -0.52246661]] [-0.00044324]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[1.1946213  0.25367192]] [-0.04850126]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 1.24945943 -0.55342029]] [-0.00260982]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 1.48188929 -0.22190969]] [-0.11415029]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 1.37474692 -0.90676623]] [-0.25188208]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 1.81521821 -0.1748609 ]] [-0.34254068]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 1.68076475 -0.94453823]] [-0.48163051]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.004751   -0.38236137]] [-0.56994954]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 1.92259519 -0.83403986]] [-0.65925009]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.03420067 -0.64729502]] [-0.69331097]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.0466266  -0.67724294]] [-0.71391434]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.06586471 -0.68402982]] [-0.73206263]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.08445826 -0.68997094]] [-0.74918943]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.10229126 -0.69561951]] [-0.76541383]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.11941228 -0.70103773]] [-0.78082084]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.13587561 -0.70624813]] [-0.79548323]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.15173059 -0.71126709]] [-0.80946465]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.16702132 -0.71610869]] [-0.82282119]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.18178724 -0.72078538]] [-0.83560249]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.19606378 -0.72530834]] [-0.8478527]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.20988285 -0.72968763]] [-0.85961126]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.2232733  -0.73393233]] [-0.87091349]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.23626131 -0.73805069]] [-0.88179117]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.24887072 -0.7420502 ]] [-0.89227298]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.26112329 -0.74593769]] [-0.90238487]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.27303891 -0.74971943]] [-0.91215041]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.28463588 -0.75340115]] [-0.92159104]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.295931   -0.75698814]] [-0.93072635]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.30693977 -0.76048526]] [-0.93957426]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
#
# [[ 2.31767654 -0.763897  ]] [-0.94815119]
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)
# <class 'numpy.ndarray'> (2,)
# <class 'numpy.ndarray'> (1,)

# %% [markdown]
# # Load data

# %%
# !ls
# Out:
# mobile_cleaned.csv  sample_data

# %%
data = pd.read_csv('mobile_cleaned.csv')
data.head()
# Out:
#    PhoneId  Pixel Density  Screen Size  Weight  RAM  Processor_frequency  \
# 0        0            403         6.26     182    4                  1.8
# 1        1            271         6.20     168    3                  1.8
# 2        2            409         6.30     168    3                  2.1
# 3        4            411         6.00     169    4                  2.2
# 4        5            396         6.50     175    4                  2.2
#
#    Screen to Body Ratio (calculated)  Height  Internal Memory  Capacity  ...  \
# 0                              80.68   157.9               64      4000  ...
# 1                              80.85   156.2               32      4230  ...
# 2                              83.68   157.0               32      3500  ...
# 3                              74.78   159.8               64      3300  ...
# 4                              84.23   160.4               64      3750  ...
#
#    os_name_Tizen  os_name_iOS  SIM Slot(s)_Dual SIM, GSM+CDMA  \
# 0              0            0                               0
# 1              0            0                               0
# 2              0            0                               0
# 3              0            0                               0
# 4              0            0                               0
#
#    SIM Slot(s)_Dual SIM, GSM+GSM  SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE  \
# 0                              0                                          1
# 1                              0                                          1
# 2                              0                                          1
# 3                              1                                          0
# 4                              0                                          1
#
#    SIM Slot(s)_Single SIM, GSM  Sim1_2G  Sim1_3G  Sim1_4G  Rating
# 0                            0        0        0        1     4.5
# 1                            0        0        0        1     4.5
# 2                            0        0        0        1     4.4
# 3                            0        0        0        1     4.3
# 4                            0        0        0        1     4.4
#
# [5 rows x 88 columns]

# %%
data.shape
# Out:
# (341, 88)

# %%
X = data.drop('Rating', axis=1)
Y = data['Rating'].values

# %%
Y
# Out:
# array([4.5, 4.5, 4.4, 4.3, 4.4, 4.5, 4.3, 4.1, 4.3, 4.5, 4.5, 4. , 4.4,
#        4.4, 4.4, 4.4, 4.5, 4.4, 4.4, 4.4, 4.4, 4.5, 4.4, 4.3, 4.2, 4.3,
#        4.3, 4.6, 4.4, 4.5, 3.9, 4.2, 4.3, 4.2, 4.3, 4.3, 4.2, 4.4, 4.1,
#        3.8, 4.4, 4.6, 4.3, 4.5, 4.5, 4.2, 3.9, 4.3, 4. , 4.3, 4.3, 3.9,
#        4.2, 4.5, 4. , 4.6, 4.2, 2.8, 4.4, 4.3, 4.2, 4.4, 4.4, 4. , 4.4,
#        4.4, 4.1, 4.5, 4.3, 3.9, 4.3, 4.1, 4.1, 4.2, 3.4, 4.2, 4.6, 3.8,
#        4.3, 4.5, 4.2, 4.5, 4.5, 4. , 4.1, 4.4, 4.5, 4.1, 4.5, 4.3, 4.5,
#        3.9, 3.9, 4.4, 4.4, 4.4, 4. , 4.1, 4.1, 4.4, 4.3, 4.3, 4.2, 4.3,
#        3.4, 4.3, 4.3, 4.2, 4.6, 4.8, 4.4, 3.4, 3.7, 4.2, 4.3, 4.4, 4.3,
#        4.2, 4.1, 4.3, 4. , 3.9, 4.4, 4.4, 3.9, 3.1, 3.7, 4.2, 4.4, 4. ,
#        4. , 4.1, 4.2, 4.3, 4.2, 4.3, 4.1, 3.6, 4.1, 4. , 3.8, 3.7, 4.3,
#        4.1, 4.1, 4.5, 4. , 4.3, 3.6, 4.1, 4.5, 3.5, 4. , 4.3, 4.6, 3.5,
#        3.9, 4.1, 3.9, 3.8, 4.4, 4.3, 4. , 3.9, 4.4, 4.7, 3.9, 4.5, 3.7,
#        4. , 4.3, 4.1, 4.8, 4.1, 4. , 4.7, 4. , 4.1, 4. , 3.4, 4.1, 3.9,
#        3.1, 4.1, 3.7, 3.4, 3.9, 4.3, 4.1, 3.7, 3.8, 4. , 3.8, 4.6, 3.4,
#        3.3, 3.2, 3.5, 4.3, 4.1, 4. , 3.8, 4.3, 4.1, 4. , 3.8, 3.8, 3.9,
#        4.1, 3.7, 4.2, 4. , 4.2, 4.4, 4.1, 3.4, 4.2, 4.4, 3.9, 3.9, 4.4,
#        4.2, 4.5, 4.5, 4.2, 4. , 4.2, 3.5, 3.7, 4.3, 5. , 3.5, 4.4, 3.7,
#        4.3, 3.9, 4.3, 3.8, 3.8, 4.3, 5. , 4.1, 3. , 4.4, 3. , 4. , 4. ,
#        3.9, 3.9, 4.2, 2.8, 4.3, 3.3, 4.3, 4. , 4.2, 4.1, 4.2, 3.6, 3.5,
#        4.1, 4.6, 3.9, 4. , 3.8, 4.1, 2.5, 4.2, 3.7, 3.9, 4.1, 3. , 3.8,
#        4.6, 4.2, 3.4, 3.9, 4.5, 4.1, 3.3, 4.1, 4. , 3.3, 4.4, 3.8, 3.9,
#        3.6, 4.4, 4.1, 4.1, 4. , 3.5, 3. , 4.2, 4. , 3.9, 3.5, 3.4, 3.4,
#        4. , 3.6, 4. , 3.5, 4. , 4. , 3.7, 4.6, 4. , 4.1, 4. , 3.5, 4.1,
#        3.7, 4.4, 4.3, 4.1, 3.9, 3.4, 3.3, 3.9, 4. , 4.4, 4.5, 4.2, 3.8,
#        3.7, 4.2, 4.1, 4. , 3.9, 3.7, 4.2, 4. , 3.6, 3.6, 4.4, 3.8, 3.9,
#        4.1, 3.6, 4.3])

# %%
threshold = 4
data['Class'] = (data['Rating'] >= threshold).astype(np.int)

# %%
data['Class'].value_counts(normalize=True)
# Out:
# 1    0.697947
# 0    0.302053
# Name: Class, dtype: float64

# %%
Y_binarized = data['Class'].values

# %% [markdown]
# # Standardization

# %%
R = np.random.random([100, 1])

# %%
plt.plot(R)
plt.show()

# %%
np.mean(R)
# Out:
# 0.4941449526995271

# %%
np.std(R)
# Out:
# 0.2707981544569339

# %%
scaler = StandardScaler()

# %%
scaler.fit(R)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaler.mean_
# Out:
# array([0.49414495])

# %%
RT = scaler.transform(R)

# %%
np.mean(RT)
# Out:
# 1.7541523789077474e-16

# %%
np.std(RT)
# Out:
# 1.0

# %%
plt.plot(RT)
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, random_state=0, stratify=Y_binarized)

# %%
print(x_train.shape, x_test.shape)
# Out:
# (255, 87) (86, 87)

# %%
scaler = StandardScaler()

"""
z = (x - u) / s

standardize the data such that mean = 0 and std = 1 , standard scaler normalizes the feature individual column in X

"""

# %%
x_scaled_train = scaler.fit_transform(x_train)
x_scaled_test = scaler.fit_transform(x_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
x_train.shape, x_scaled_train.shape
# Out:
# ((255, 87), (255, 87))

# %%
x_train
# Out:
#      PhoneId  Pixel Density  Screen Size  Weight  RAM  Processor_frequency  \
# 279      386            295         5.45     161    2                 1.30
# 173      234            441         5.00     145    3                 1.40
# 41        58            531         6.20     189    6                 2.70
# 76        99            456         6.50     208    4                 2.49
# 91       118            554         5.30     160    4                 2.45
# 49        66            294         5.60     154    4                 1.60
# 6          8            295         5.45     145    2                 2.00
# 207      283            453         4.50     196    3                 2.20
# 296      411            218         4.50     161    1                 1.30
# 116      156            402         6.28     161    6                 2.20
# 114      150            407         5.93     168    6                 2.20
# 15        21            435         5.80     151    4                 1.80
# 274      378            424         5.20     136    2                 1.80
# 265      369            294         5.00     138    3                 1.50
# 301      417            294         5.00     136    1                 1.50
# 56        74            268         6.00     150    3                 1.40
# 50        67            269         5.99     160    4                 1.80
# 326      451            294         5.60     162    4                 1.60
# 94       124            409         6.30     169    6                 2.00
# 115      155            396         6.50     175    6                 2.20
# 13        18            400         6.30     150    4                 2.20
# 8         10            271         6.20     168    2                 1.80
# 46        63            167         2.40     161  512                 1.00
# 65        86            426         5.84     160    4                 1.80
# 248      343            401         5.50     170    4                 1.40
# 263      366            197         5.45     145    2                 1.30
# 98       130            295         5.45     138    2                 1.50
# 316      439            294         5.00     154    2                 1.30
# 35        52            400         6.30     150    6                 1.95
# 249      346            282         5.70     143    4                 2.50
# ..       ...            ...          ...     ...  ...                  ...
# 171      232            143         2.80     161    8                 1.79
# 233      319            282         5.20     162    4                 1.50
# 219      300            268         6.00     150    4                 2.00
# 74        97            167         2.40      58  512                 1.10
# 100      133            326         4.70     129    1                 1.40
# 253      350            267         5.50     175    3                 1.40
# 311      429            294         5.00     161    2                 1.00
# 272      376            367         6.00     202    3                 2.00
# 240      329            424         5.70     198    6                 2.80
# 162      220            386         5.70     151    2                 1.80
# 83       108            277         5.30     161    3                 1.30
# 232      317            405         6.23     158    6                 2.00
# 89       115            409         5.90     164    4                 2.36
# 163      221            295         5.45     161    3                 1.50
# 284      395            401         5.50     172    4                 1.80
# 243      333            401         5.50     165    3                 2.00
# 231      315            294         5.00     163    3                 1.25
# 322      446            531         6.20     173    6                 2.30
# 170      229            401         5.50     161    4                 2.00
# 64        85            402         6.00     155    6                 2.00
# 97       129            295         5.45     161    2                 1.50
# 93       123            534         5.50     157    4                 2.30
# 51        68            403         5.99     168    6                 2.20
# 184      248            233         4.00     124  512                 1.30
# 236      324            294         5.00     155    2                 1.40
# 205      281            439         5.50     149    4                 1.40
# 329      454            294         5.00     161    2                 1.30
# 335      462            268         6.00     161    3                 1.40
# 77       100            424         5.70     167    3                 1.80
# 175      237            271         6.20     161    2                 2.00
#
#      Screen to Body Ratio (calculated)      Height  Internal Memory  Capacity  \
# 279                              72.39  148.300000               16      2800
# 173                              68.93  141.900000               32      4000
# 41                               83.99  158.100000               64      3500
# 76                               84.89  157.500000               64      3174
# 91                               69.19  151.500000               64      3090
# 49                               76.28  149.300000               64      3000
# 6                                72.68  147.500000               16      3000
# 207                              56.52  128.000000               32      3450
# 296                              72.35  149.946394                8      1300
# 116                              84.93  154.400000              128      3200
# 114                              74.66  161.000000               64      3200
# 15                               80.05  147.200000               64      3060
# 274                              69.69  147.000000               32      2700
# 265                              67.44  143.600000               32      2550
# 301                              66.74  144.300000               16      2500
# 56                               78.62  155.900000               16      3360
# 50                               78.51  155.800000               64      3225
# 326                              75.33  149.900000               64      3000
# 94                               83.84  156.700000              128      3500
# 115                              84.23  160.400000               64      3750
# 13                               84.87  154.810000               64      3260
# 8                                80.85  156.200000               16      4230
# 46                               72.35  149.946394                4      2000
# 65                               80.65  149.700000               64      3060
# 248                              70.85  153.700000               64      4070
# 263                              71.55  148.800000               16      2500
# 98                               72.95  148.000000               16      3050
# 316                              66.00  144.300000               16      3000
# 35                               84.91  154.800000               64      3260
# 249                              76.21  150.500000               64      3180
# ..                                 ...         ...              ...       ...
# 171                              35.30  124.000000               32      1200
# 233                              69.31  147.600000               64      3000
# 219                              77.28  158.600000               64      3750
# 74                               23.60  134.000000                4      2000
# 100                              66.14  137.100000               32      1810
# 253                              71.04  151.700000               32      3000
# 311                              66.78  143.800000               16      3500
# 272                              75.95  164.200000               16      2700
# 240                              76.11  153.000000               64      3180
# 162                              73.64  158.000000               32      3050
# 83                               69.00  150.500000               32      4000
# 232                              82.06  156.000000              128      3400
# 89                               76.48  156.200000               64      3340
# 163                              73.05  148.000000               32      4000
# 284                              71.98  153.300000               32      4000
# 243                              72.50  151.000000               32      4100
# 231                              66.97  144.200000               32      4000
# 322                              83.70  159.500000              128      3500
# 170                              73.73  152.500000               64      3055
# 64                               78.94  156.500000              128      3410
# 97                               73.05  148.000000               16      4000
# 93                               75.94  150.900000               32      3600
# 51                               77.38  158.700000              128      3010
# 184                              59.24  123.000000                4      1700
# 236                              66.83  142.100000               16      2470
# 205                              79.05  142.500000               64      3000
# 329                              65.96  145.400000               16      2400
# 335                              75.91  160.400000               32      4000
# 77                               75.40  153.800000               32      3000
# 175                              72.35  149.946394               32      3750
#
#      ...  os_name_Other  os_name_Tizen  os_name_iOS  \
# 279  ...              0              0            0
# 173  ...              0              0            0
# 41   ...              0              0            0
# 76   ...              0              0            1
# 91   ...              0              0            0
# 49   ...              0              0            0
# 6    ...              0              0            0
# 207  ...              0              0            0
# 296  ...              0              0            0
# 116  ...              0              0            0
# 114  ...              0              0            0
# 15   ...              0              0            0
# 274  ...              0              0            0
# 265  ...              0              0            0
# 301  ...              0              0            0
# 56   ...              0              0            0
# 50   ...              0              0            0
# 326  ...              0              0            0
# 94   ...              0              0            0
# 115  ...              0              0            0
# 13   ...              0              0            0
# 8    ...              0              0            0
# 46   ...              0              0            0
# 65   ...              0              0            0
# 248  ...              0              0            0
# 263  ...              0              0            0
# 98   ...              0              0            0
# 316  ...              0              0            0
# 35   ...              0              0            0
# 249  ...              0              0            0
# ..   ...            ...            ...          ...
# 171  ...              1              0            0
# 233  ...              0              0            0
# 219  ...              0              0            0
# 74   ...              1              0            0
# 100  ...              0              0            1
# 253  ...              0              0            0
# 311  ...              0              0            0
# 272  ...              0              0            0
# 240  ...              0              0            0
# 162  ...              0              0            0
# 83   ...              0              0            0
# 232  ...              0              0            0
# 89   ...              0              0            0
# 163  ...              0              0            0
# 284  ...              0              0            0
# 243  ...              0              0            0
# 231  ...              0              0            0
# 322  ...              0              0            0
# 170  ...              0              0            0
# 64   ...              0              0            0
# 97   ...              0              0            0
# 93   ...              0              0            0
# 51   ...              0              0            0
# 184  ...              0              0            0
# 236  ...              0              0            0
# 205  ...              0              0            0
# 329  ...              0              0            0
# 335  ...              0              0            0
# 77   ...              0              0            0
# 175  ...              0              0            0
#
#      SIM Slot(s)_Dual SIM, GSM+CDMA  SIM Slot(s)_Dual SIM, GSM+GSM  \
# 279                               0                              1
# 173                               0                              1
# 41                                0                              0
# 76                                0                              1
# 91                                0                              1
# 49                                0                              1
# 6                                 0                              0
# 207                               0                              0
# 296                               0                              1
# 116                               0                              1
# 114                               0                              1
# 15                                0                              0
# 274                               0                              0
# 265                               0                              1
# 301                               0                              1
# 56                                0                              1
# 50                                0                              1
# 326                               0                              1
# 94                                0                              0
# 115                               0                              0
# 13                                0                              1
# 8                                 0                              1
# 46                                0                              0
# 65                                0                              0
# 248                               0                              1
# 263                               0                              1
# 98                                0                              0
# 316                               0                              1
# 35                                0                              1
# 249                               0                              1
# ..                              ...                            ...
# 171                               0                              1
# 233                               0                              1
# 219                               0                              1
# 74                                0                              1
# 100                               0                              0
# 253                               0                              1
# 311                               0                              1
# 272                               0                              1
# 240                               0                              1
# 162                               0                              1
# 83                                0                              1
# 232                               0                              0
# 89                                0                              1
# 163                               0                              0
# 284                               0                              1
# 243                               0                              1
# 231                               0                              1
# 322                               0                              1
# 170                               0                              1
# 64                                0                              0
# 97                                0                              0
# 93                                0                              1
# 51                                0                              0
# 184                               0                              1
# 236                               0                              1
# 205                               0                              1
# 329                               0                              1
# 335                               0                              1
# 77                                0                              1
# 175                               0                              0
#
#      SIM Slot(s)_Dual SIM, GSM+GSM, Dual VoLTE  SIM Slot(s)_Single SIM, GSM  \
# 279                                          0                            0
# 173                                          0                            0
# 41                                           1                            0
# 76                                           0                            0
# 91                                           0                            0
# 49                                           0                            0
# 6                                            1                            0
# 207                                          0                            1
# 296                                          0                            0
# 116                                          0                            0
# 114                                          0                            0
# 15                                           1                            0
# 274                                          0                            1
# 265                                          0                            0
# 301                                          0                            0
# 56                                           0                            0
# 50                                           0                            0
# 326                                          0                            0
# 94                                           1                            0
# 115                                          1                            0
# 13                                           0                            0
# 8                                            0                            0
# 46                                           0                            1
# 65                                           1                            0
# 248                                          0                            0
# 263                                          0                            0
# 98                                           1                            0
# 316                                          0                            0
# 35                                           0                            0
# 249                                          0                            0
# ..                                         ...                          ...
# 171                                          0                            0
# 233                                          0                            0
# 219                                          0                            0
# 74                                           0                            0
# 100                                          0                            1
# 253                                          0                            0
# 311                                          0                            0
# 272                                          0                            0
# 240                                          0                            0
# 162                                          0                            0
# 83                                           0                            0
# 232                                          1                            0
# 89                                           0                            0
# 163                                          1                            0
# 284                                          0                            0
# 243                                          0                            0
# 231                                          0                            0
# 322                                          0                            0
# 170                                          0                            0
# 64                                           1                            0
# 97                                           1                            0
# 93                                           0                            0
# 51                                           1                            0
# 184                                          0                            0
# 236                                          0                            0
# 205                                          0                            0
# 329                                          0                            0
# 335                                          0                            0
# 77                                           0                            0
# 175                                          1                            0
#
#      Sim1_2G  Sim1_3G  Sim1_4G
# 279        0        0        1
# 173        0        0        1
# 41         0        0        1
# 76         0        0        1
# 91         0        0        1
# 49         0        0        1
# 6          0        0        1
# 207        0        0        1
# 296        0        0        1
# 116        0        0        1
# 114        0        0        1
# 15         0        0        1
# 274        0        0        1
# 265        0        0        1
# 301        0        0        1
# 56         0        0        1
# 50         0        0        1
# 326        0        0        1
# 94         0        0        1
# 115        0        0        1
# 13         0        0        1
# 8          0        0        1
# 46         0        0        1
# 65         0        0        1
# 248        0        0        1
# 263        0        0        1
# 98         0        0        1
# 316        0        0        1
# 35         0        0        1
# 249        0        0        1
# ..       ...      ...      ...
# 171        1        0        0
# 233        0        0        1
# 219        0        0        1
# 74         0        0        1
# 100        0        0        1
# 253        0        0        1
# 311        0        0        1
# 272        0        0        1
# 240        0        0        1
# 162        0        0        1
# 83         0        0        1
# 232        0        0        1
# 89         0        0        1
# 163        0        0        1
# 284        0        0        1
# 243        0        0        1
# 231        0        0        1
# 322        0        0        1
# 170        0        0        1
# 64         0        0        1
# 97         0        0        1
# 93         0        0        1
# 51         0        0        1
# 184        0        1        0
# 236        0        0        1
# 205        0        0        1
# 329        0        0        1
# 335        0        0        1
# 77         0        0        1
# 175        0        0        1
#
# [255 rows x 87 columns]

# %%
x_scaled_train
# Out:
# array([[ 1.11419745e+00, -5.65286543e-01, -1.67994477e-03, ...,
#         -1.55230105e-01, -1.26238881e-01,  2.02030509e-01],
#        [-4.03903788e-03,  1.08483248e+00, -5.85842559e-01, ...,
#         -1.55230105e-01, -1.26238881e-01,  2.02030509e-01],
#        [-1.29883918e+00,  2.10202914e+00,  9.71924412e-01, ...,
#         -1.55230105e-01, -1.26238881e-01,  2.02030509e-01],
#        ...,
#        [ 1.67331569e+00, -8.70445540e-01,  7.12296583e-01, ...,
#         -1.55230105e-01, -1.26238881e-01,  2.02030509e-01],
#        [-9.89852784e-01,  8.92695332e-01,  3.22854841e-01, ...,
#         -1.55230105e-01, -1.26238881e-01,  2.02030509e-01],
#        [ 1.80314191e-02, -8.36538985e-01,  9.71924412e-01, ...,
#         -1.55230105e-01, -1.26238881e-01,  2.02030509e-01]])

# %%
minmax_scaler = MinMaxScaler()

"""
minmax scaler scales the feature of with min and max of the column

using formula

X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))

X_scaled = X_std * (max - min) + min

"""

# %%
y_scaled_train = minmax_scaler.fit_transform(y_train.reshape(-1, 1))

# %%
np.min(y_scaled_train)
# Out:
# 0.0

# %%
np.max(y_scaled_train)
# Out:
# 0.9999999999999998

# %%
y_scaled_test = minmax_scaler.transform(y_test.reshape(-1, 1))

# %%
scaled_threshold = list(minmax_scaler.transform(np.array([threshold]).reshape(1, -1)))[0][0]
scaled_threshold
# Out:
# 0.5454545454545454

# %%
y_binarized_train = (y_scaled_train > scaled_threshold).astype("int").ravel()

# %%
y_binarized_test = (y_scaled_test > scaled_threshold).astype("int").ravel()

# %% [markdown]
# # Training on Real Data

# %%
sn = SigmoidNeuron()

# %%
x_scaled_train.shape, y_scaled_train.shape
# Out:
# ((255, 87), (255, 1))

# %%
sn.fit(x_scaled_train, y_scaled_train, epochs=2000, learning_rate=0.015, display_loss=True)
# Out:
# HBox(children=(IntProgress(value=0, max=2000), HTML(value='')))

# %%
y_pred_train = sn.predict(x_scaled_train)
y_pred_test = sn.predict(x_scaled_test)

# %%
y_pred_binarized_train = (y_pred_train > scaled_threshold).astype("int").ravel()
y_pred_binarized_test = (y_pred_test > scaled_threshold).astype("int").ravel()

# ravel returns a flattened array

# %%
accuracy_train = accuracy_score(y_pred_binarized_train, y_binarized_train)
accuracy_test = accuracy_score(y_pred_binarized_test, y_binarized_test)

# %%
print(accuracy_train, accuracy_test)
# Out:
# 0.8156862745098039 0.6046511627906976
