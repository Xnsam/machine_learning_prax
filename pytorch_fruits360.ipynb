# %% [markdown]
# # Set up

# %%
# !pip install -U -q kaggle

# %%
# !mkdir -p ~/.kaggle
# !echo '{"username":"aksonsam","key":"bf611cb9849cb706c0fd16c854cd9e21"}' > ~/.kaggle/kaggle.json
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d moltean/fruits
# Out:
# Downloading fruits.zip to /content
#  98% 679M/690M [00:15<00:00, 44.6MB/s]
# 100% 690M/690M [00:15<00:00, 47.3MB/s]

# %%
# !mkdir data
# !unzip -d data -q fruits.zip

# %% [markdown]
# # Data

# %%
import glob

# %%
train_files = glob.glob('data/fruits-360/Training/*/*')
test_files = glob.glob('data/fruits-360/Test/*/*')

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
np.random.shuffle(train_files)
np.random.shuffle(test_files)

# %%
for i in range(10):
  plt.subplot(2, 5, i+1)
  plt.imshow(plt.imread(train_files[i]))
plt.show()

# %%
for i in range(10):
  plt.subplot(2, 5, i+1)
  plt.imshow(plt.imread(test_files[i]))
plt.show()

# %%
import torch
import torchvision

from torchvision import transforms

# %%
# data_transforms = {
#     'Training': transforms.Compose([
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#     ]),
#     'Test':transforms.Compose([
#         transforms.ToTensor(),
#         transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
#     ])
# }

train_trans = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(0.3, 0.3, 0.3),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.485, 0.485], [0.229, 0.229, 0.229])
])


test_trans = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.485, 0.485], [0.229, 0.229, 0.229])
])

train_set_fruits = torchvision.datasets.ImageFolder('data/fruits-360/Training', transform=train_trans)
test_set_fruits = torchvision.datasets.ImageFolder('data/fruits-360/Test', transform=test_trans)

# %%
train_size = int(0.9 * len(train_set_fruits))
test_size = len(train_set_fruits) - train_size

train_fruits_data, val_fruits_data = torch.utils.data.random_split(train_set_fruits, [train_size, test_size])

len(train_fruits_data), len(val_fruits_data)
# Out:
# (48664, 5408)

# %%
# data_dir = 'data/fruits-360'
# image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['Training', 'Test']}

# dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4, shuffle=True, num_workers=4) for x in ['Training', 'Test']}

# class_names = image_datasets['Training'].classes

batch_size=128

train_fruit_loaders = torch.utils.data.DataLoader(train_fruits_data, batch_size=batch_size, shuffle=True)
val_fruit_loaders = torch.utils.data.DataLoader(val_fruits_data, batch_size=batch_size, shuffle=True)
test_fruit_loaders = torch.utils.data.DataLoader(test_set_fruits, batch_size=batch_size, shuffle=False)

class_names = train_set_fruits.classes

# %%
class_names = dict((i, v) for i, v in enumerate(train_set_fruits.classes))

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
def imshow(inp, title=None):
  """Imshow for tensor."""
  inp = inp.numpy().transpose((1, 2, 0))
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
  inp = std * inp + mean
  inp = np.clip(inp, 0, 1)
  plt.imshow(inp)
  if title is not None:
    plt.title(title)
  plt.pause(0.001)

# %%
inputs, classes = next(iter(train_fruit_loaders))

# out = torchvision.utils.make_grid(inputs)

# imshow(out, title=[class_names[x.item()] for x in classes])

# %%
inputs, classes = next(iter(train_fruit_loaders))
inputs.shape
# Out:
# torch.Size([128, 3, 100, 100])

# %% [markdown]
# # Training

# %% [markdown]
# ## resnet model

# %%
def get_trainable(model_params):
  return (p for p in model_params if p.requires_grad)

def get_frozen(model_params):
  return (p for p in model_params if not p.requires_grad)

def all_trainable(model_params):
  return all(p.requires_grad for p in model_params)

def all_frozen(model_params):
  return all(not p.requires_grad for p in model_params)

def freeze_all(model_params):
  for param in model_params:
    param.requires_grad = False

# %%
from torchvision import models

# %%
n_classes = len(class_names)
n_classes
# Out:
# 105

# %%
def get_model(n_classes):
  model = models.resnet18(pretrained=True)
  freeze_all(model.parameters())
  model.fc = torch.nn.Linear(512, n_classes)
  model = model.to(device)
  return model

# %%
resnet18_fruits_model = get_model(n_classes)

# %%
inputs.shape
# Out:
# torch.Size([128, 3, 100, 100])

# %%
import torchsummary

torchsummary.summary(resnet18_fruits_model, inputs.shape[1:])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 50, 50]           9,408
#        BatchNorm2d-2           [-1, 64, 50, 50]             128
#               ReLU-3           [-1, 64, 50, 50]               0
#          MaxPool2d-4           [-1, 64, 25, 25]               0
#             Conv2d-5           [-1, 64, 25, 25]          36,864
#        BatchNorm2d-6           [-1, 64, 25, 25]             128
#               ReLU-7           [-1, 64, 25, 25]               0
#             Conv2d-8           [-1, 64, 25, 25]          36,864
#        BatchNorm2d-9           [-1, 64, 25, 25]             128
#              ReLU-10           [-1, 64, 25, 25]               0
#        BasicBlock-11           [-1, 64, 25, 25]               0
#            Conv2d-12           [-1, 64, 25, 25]          36,864
#       BatchNorm2d-13           [-1, 64, 25, 25]             128
#              ReLU-14           [-1, 64, 25, 25]               0
#            Conv2d-15           [-1, 64, 25, 25]          36,864
#       BatchNorm2d-16           [-1, 64, 25, 25]             128
#              ReLU-17           [-1, 64, 25, 25]               0
#        BasicBlock-18           [-1, 64, 25, 25]               0
#            Conv2d-19          [-1, 128, 13, 13]          73,728
#       BatchNorm2d-20          [-1, 128, 13, 13]             256
#              ReLU-21          [-1, 128, 13, 13]               0
#            Conv2d-22          [-1, 128, 13, 13]         147,456
#       BatchNorm2d-23          [-1, 128, 13, 13]             256
#            Conv2d-24          [-1, 128, 13, 13]           8,192
#       BatchNorm2d-25          [-1, 128, 13, 13]             256
#              ReLU-26          [-1, 128, 13, 13]               0
#        BasicBlock-27          [-1, 128, 13, 13]               0
#            Conv2d-28          [-1, 128, 13, 13]         147,456
#       BatchNorm2d-29          [-1, 128, 13, 13]             256
#              ReLU-30          [-1, 128, 13, 13]               0
#            Conv2d-31          [-1, 128, 13, 13]         147,456
#       BatchNorm2d-32          [-1, 128, 13, 13]             256
#              ReLU-33          [-1, 128, 13, 13]               0
#        BasicBlock-34          [-1, 128, 13, 13]               0
#            Conv2d-35            [-1, 256, 7, 7]         294,912
#       BatchNorm2d-36            [-1, 256, 7, 7]             512
#              ReLU-37            [-1, 256, 7, 7]               0
#            Conv2d-38            [-1, 256, 7, 7]         589,824
#       BatchNorm2d-39            [-1, 256, 7, 7]             512
#            Conv2d-40            [-1, 256, 7, 7]          32,768
#       BatchNorm2d-41            [-1, 256, 7, 7]             512
#              ReLU-42            [-1, 256, 7, 7]               0
#        BasicBlock-43            [-1, 256, 7, 7]               0
#            Conv2d-44            [-1, 256, 7, 7]         589,824
#       BatchNorm2d-45            [-1, 256, 7, 7]             512
#              ReLU-46            [-1, 256, 7, 7]               0
#            Conv2d-47            [-1, 256, 7, 7]         589,824
#       BatchNorm2d-48            [-1, 256, 7, 7]             512
#              ReLU-49            [-1, 256, 7, 7]               0
#        BasicBlock-50            [-1, 256, 7, 7]               0
#            Conv2d-51            [-1, 512, 4, 4]       1,179,648
#       BatchNorm2d-52            [-1, 512, 4, 4]           1,024
#              ReLU-53            [-1, 512, 4, 4]               0
#            Conv2d-54            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-55            [-1, 512, 4, 4]           1,024
#            Conv2d-56            [-1, 512, 4, 4]         131,072
#       BatchNorm2d-57            [-1, 512, 4, 4]           1,024
#              ReLU-58            [-1, 512, 4, 4]               0
#        BasicBlock-59            [-1, 512, 4, 4]               0
#            Conv2d-60            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-61            [-1, 512, 4, 4]           1,024
#              ReLU-62            [-1, 512, 4, 4]               0
#            Conv2d-63            [-1, 512, 4, 4]       2,359,296
#       BatchNorm2d-64            [-1, 512, 4, 4]           1,024
#              ReLU-65            [-1, 512, 4, 4]               0
#        BasicBlock-66            [-1, 512, 4, 4]               0
# AdaptiveAvgPool2d-67            [-1, 512, 1, 1]               0
#            Linear-68                  [-1, 105]          53,865
# ================================================================
# Total params: 11,230,377
# Trainable params: 53,865
# Non-trainable params: 11,176,512
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 13.42
# Params size (MB): 42.84
# Estimated Total Size (MB): 56.37
# ----------------------------------------------------------------

# %%
criterion = torch.nn.CrossEntropyLoss()

# %%
optimizer = torch.optim.Adam(get_trainable(resnet18_fruits_model.parameters()), lr=1e-3, weight_decay=1e-3//batch_size)

# %%
# %matplotlib inline

# %%
from tqdm import tqdm_notebook as tqdm
import sys

# %%
def run_model1(n_epochs):
  """Function to run the model training loop."""
  for epoch in range(n_epochs):
    print('Epoch {} /{} ----'.format(epoch +1, n_epochs))
    print()

    resnet18_fruits_model.train()

    running_loss, correct = 0.0, 0
    with tqdm(total=len(train_fruit_loaders.dataset)//batch_size) as pbar:
      for i, data in enumerate(train_fruit_loaders, 0):
        pbar.set_description('Batches: %d  ' % (1 + i))
        pbar.update(1)
        # set_trace()
        img, labels = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        y_ = resnet18_fruits_model(img)
        loss = criterion(y_, labels)
        loss.backward()
        optimizer.step()

        # statistics
        # print(f"batch loss: {loss.item():0.3f}")
        _, y_label_ = torch.max(y_, 1)
        correct += (y_label_ == labels).sum().item()
        running_loss += loss.item() * img.shape[0]
      print(f" Train Loss: {running_loss/len(train_fruit_loaders.dataset)}")
      print(f" Train Acc : {correct / len(train_fruit_loaders.dataset)}")

    resnet18_fruits_model.eval()

    if epoch % 5 == 0:
      print('Checking on validation data ---')
      print('-'*10)
      running_loss, correct = 0.0, 0
      with tqdm(total=len(val_fruit_loaders.dataset)//batch_size, file=sys.stdout) as pbar:
        with torch.no_grad():
          for i, data in enumerate(val_fruit_loaders, 0):
            pbar.set_description('Validation Batches: %d  ' % (1 + i))
            pbar.update(1)
            x, y = data[0].to(device), data[1].to(device)
            y_ = resnet18_fruits_model(x)
            # statistics
            _, y_label_ = torch.max(y_, 1)
            correct += (y_label_ == y).sum().item()
            loss = criterion(y_, y)
            running_loss += loss.item() * x.shape[0]
          print(f"Valid Loss: {running_loss/len(val_fruit_loaders.dataset)}")
          print(f"Valid Acc: {correct/len(val_fruit_loaders.dataset)}")
          print()

# %%
n_epochs = 20

run_model1(n_epochs)
# Out:
# Epoch 1 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.4246673547423495
#  Train Acc : 0.9534358047016275
#
# Checking on validation data ---
# ----------
# HBox(children=(IntProgress(value=0, max=42), HTML(value='')))
# Valid Loss: 0.10403592769916241
# Valid Acc: 0.9938979289940828
#
#
# Epoch 2 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.07813382939670248
#  Train Acc : 0.9933626500082197
#
# Epoch 3 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.04127176556342451
#  Train Acc : 0.9971642281768864
#
# Epoch 4 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.0279646073955661
#  Train Acc : 0.9977190530987999
#
# Epoch 5 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.020877683583292426
#  Train Acc : 0.9985204668748973
#
# Epoch 6 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.016379735319728663
#  Train Acc : 0.9984588196613513
#
# Checking on validation data ---
# ----------
# HBox(children=(IntProgress(value=0, max=42), HTML(value='')))
# Valid Loss: 0.009954034190999685
# Valid Acc: 0.9994452662721893
#
#
# Epoch 7 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.013014444648073081
#  Train Acc : 0.9989314482985369
#
# Epoch 8 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.010881823948877689
#  Train Acc : 0.9989930955120828
#
# Epoch 9 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.009805244895976055
#  Train Acc : 0.9989108992273549
#
# Epoch 10 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.00798630389992283
#  Train Acc : 0.9991369390103567
#
# Epoch 11 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.007125623884286101
#  Train Acc : 0.9991780371527207
#
# Checking on validation data ---
# ----------
# HBox(children=(IntProgress(value=0, max=42), HTML(value='')))
# Valid Loss: 0.005281491579829588
# Valid Acc: 0.9996301775147929
#
#
# Epoch 12 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.006787330337274791
#  Train Acc : 0.9990752917968108
#
# Epoch 13 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.0052591862067269115
#  Train Acc : 0.9994246260069045
#
# Epoch 14 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.005588134176321493
#  Train Acc : 0.9991163899391747
#
# Epoch 15 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.004345702212560706
#  Train Acc : 0.9994451750780865
#
# Epoch 16 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.004021077289321962
#  Train Acc : 0.9995890185763604
#
# Checking on validation data ---
# ----------
# HBox(children=(IntProgress(value=0, max=42), HTML(value='')))
# Valid Loss: 0.003474163846250557
# Valid Acc: 0.9990754437869822
#
#
# Epoch 17 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.0038627962631169756
#  Train Acc : 0.9994657241492685
#
# Epoch 18 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.003927005359974324
#  Train Acc : 0.9993424297221766
#
# Epoch 19 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.0035434905970880962
#  Train Acc : 0.9995479204339964
#
# Epoch 20 /20 ----
# HBox(children=(IntProgress(value=0, max=380), HTML(value='')))
#  Train Loss: 0.003942012847943568
#  Train Acc : 0.9992396843662666

# %%
from sklearn.metrics import classification_report

# %%
for x, y in test_fruit_loaders:
  print(x.shape, y.shape)

# %%
y_preds = []
y_trues = []
with torch.no_grad():
  for x, y in test_fruit_loaders:
    x = x.to(device)
    y_pred = resnet18_fruits_model(x)
    y_pred = list(torch.argmax(y_pred, dim=1).cpu().numpy())
    y_true = list(y.numpy())
    y_preds.extend(y_pred)
    y_trues.extend(y_true)

print(classification_report(y_trues, y_preds, target_names=list(class_names.values())))
# Out:
#                      precision    recall  f1-score   support
#
#      Apple Braeburn       0.85      0.99      0.92       164
#  Apple Crimson Snow       1.00      1.00      1.00       148
#      Apple Golden 1       1.00      0.99      1.00       164
#      Apple Golden 2       1.00      0.97      0.98       164
#      Apple Golden 3       0.82      1.00      0.90       161
#  Apple Granny Smith       0.97      0.84      0.90       164
#     Apple Pink Lady       0.98      1.00      0.99       152
#         Apple Red 1       0.96      0.99      0.97       164
#         Apple Red 2       0.96      0.85      0.90       164
#         Apple Red 3       1.00      0.99      0.99       144
# Apple Red Delicious       1.00      1.00      1.00       166
#  Apple Red Yellow 1       1.00      1.00      1.00       164
#  Apple Red Yellow 2       1.00      1.00      1.00       219
#             Apricot       1.00      1.00      1.00       164
#             Avocado       1.00      1.00      1.00       143
#        Avocado ripe       0.99      1.00      1.00       166
#              Banana       0.94      1.00      0.97       166
#  Banana Lady Finger       1.00      0.93      0.97       152
#          Banana Red       1.00      1.00      1.00       166
#        Cactus fruit       1.00      1.00      1.00       166
#        Cantaloupe 1       1.00      1.00      1.00       164
#        Cantaloupe 2       1.00      1.00      1.00       164
#           Carambula       1.00      1.00      1.00       166
#            Cherry 1       1.00      1.00      1.00       164
#            Cherry 2       0.96      1.00      0.98       246
#      Cherry Rainier       1.00      0.97      0.98       246
#    Cherry Wax Black       1.00      1.00      1.00       164
#      Cherry Wax Red       1.00      1.00      1.00       164
#   Cherry Wax Yellow       1.00      1.00      1.00       164
#            Chestnut       1.00      1.00      1.00       153
#          Clementine       1.00      0.95      0.97       166
#               Cocos       1.00      0.98      0.99       166
#               Dates       1.00      1.00      1.00       166
#          Granadilla       0.97      1.00      0.98       166
#          Grape Blue       1.00      1.00      1.00       328
#          Grape Pink       0.99      1.00      1.00       164
#         Grape White       0.95      1.00      0.98       166
#       Grape White 2       1.00      1.00      1.00       166
#       Grape White 3       0.99      1.00      1.00       164
#       Grape White 4       1.00      1.00      1.00       158
#     Grapefruit Pink       1.00      1.00      1.00       166
#    Grapefruit White       0.99      1.00      1.00       164
#               Guava       1.00      1.00      1.00       166
#            Hazelnut       1.00      1.00      1.00       157
#         Huckleberry       1.00      1.00      1.00       166
#                Kaki       1.00      0.89      0.94       166
#                Kiwi       0.98      1.00      0.99       156
#            Kohlrabi       1.00      1.00      1.00       157
#            Kumquats       1.00      1.00      1.00       166
#               Lemon       0.99      1.00      1.00       164
#         Lemon Meyer       1.00      1.00      1.00       166
#               Limes       1.00      1.00      1.00       166
#              Lychee       1.00      1.00      1.00       166
#           Mandarine       1.00      1.00      1.00       166
#               Mango       1.00      1.00      1.00       166
#           Mangostan       1.00      1.00      1.00       102
#            Maracuja       0.97      0.97      0.97       166
#  Melon Piel de Sapo       1.00      1.00      1.00       246
#            Mulberry       1.00      1.00      1.00       164
#           Nectarine       0.97      0.97      0.97       164
#           Onion Red       1.00      1.00      1.00       150
#    Onion Red Peeled       1.00      1.00      1.00       155
#              Orange       1.00      1.00      1.00       160
#              Papaya       1.00      1.00      1.00       164
#       Passion Fruit       1.00      0.95      0.97       166
#               Peach       0.99      0.99      0.99       164
#             Peach 2       1.00      1.00      1.00       246
#          Peach Flat       0.87      0.98      0.92       164
#                Pear       1.00      0.87      0.93       164
#          Pear Abate       1.00      1.00      1.00       166
#         Pear Kaiser       1.00      1.00      1.00       102
#        Pear Monster       1.00      1.00      1.00       166
#            Pear Red       1.00      1.00      1.00       222
#       Pear Williams       1.00      1.00      1.00       166
#              Pepino       1.00      0.90      0.95       166
#        Pepper Green       1.00      1.00      1.00       148
#          Pepper Red       1.00      1.00      1.00       222
#       Pepper Yellow       1.00      1.00      1.00       222
#            Physalis       1.00      1.00      1.00       164
#  Physalis with Husk       0.99      1.00      1.00       164
#           Pineapple       1.00      1.00      1.00       166
#      Pineapple Mini       1.00      1.00      1.00       163
#        Pitahaya Red       1.00      1.00      1.00       166
#                Plum       0.99      1.00      1.00       151
#              Plum 2       1.00      1.00      1.00       142
#              Plum 3       0.98      1.00      0.99       304
#         Pomegranate       0.99      0.96      0.98       164
#      Pomelo Sweetie       1.00      1.00      1.00       153
#              Quince       1.00      1.00      1.00       166
#            Rambutan       1.00      1.00      1.00       164
#           Raspberry       1.00      1.00      1.00       166
#          Redcurrant       1.00      1.00      1.00       164
#               Salak       0.99      1.00      1.00       162
#          Strawberry       1.00      1.00      1.00       164
#    Strawberry Wedge       1.00      0.99      1.00       246
#           Tamarillo       1.00      1.00      1.00       166
#             Tangelo       1.00      1.00      1.00       166
#            Tomato 1       0.98      1.00      0.99       246
#            Tomato 2       0.97      1.00      0.98       225
#            Tomato 3       1.00      0.98      0.99       246
#            Tomato 4       1.00      1.00      1.00       160
#   Tomato Cherry Red       1.00      1.00      1.00       164
#       Tomato Maroon       1.00      1.00      1.00       127
#       Tomato Yellow       1.00      1.00      1.00       153
#              Walnut       1.00      1.00      1.00       249
#
#            accuracy                           0.99     18150
#           macro avg       0.99      0.99      0.99     18150
#        weighted avg       0.99      0.99      0.99     18150
